# %% [markdown]
# # Cognifyz Technologies

# %% [markdown]
# # Data Analyst Intern

# %% [markdown]
#     Exciting Data Analysis Internship program!
#     To complete this internship, I have choose Level 1, Level 3.
#
#     TASK LIST'S
#
#     Level 1
#     Task 1 Top Cuisines
#
#         Que 1] Determine the top three most common cuisines in the dataset.
#         Que 2] Calculate the percentage of restaurants that serve each of the top cuisines.
#
#     Task 2 City Analysis
#
#         Que 1] Identify the city with the highest number of restaurants in the dataset.
#         Que 2] Calculate the average rating for restaurants in each city.
#         Que 3] Determine the city with the highest average rating.
#
#     Task 3 Price Range Distribution
#
#         Que 1] Create a histogram or bar chart to visualize the distribution of price ranges among the restaurants.
#         Que 2] Calculate the percentage of restaurants in each price range category.
#
#     Task 4 Online Delivery
#
#         Que 1] Determine the percentage of restaurants that offer online delivery.
#         Que 2] Compare the average ratings of restaurants with and without online delivery.
#
#     Level 3
#
#     Task 1 Restaurant Reviews
#
#         Que 1] Analyze the text reviews to identify the most common positive and negative keywords.
#         Que 2] Calculate the average length of reviews and explore if there is a relationship between review length and rating.
#
#     Task 2 Votes Analysis
#
#         Que 1] Identify the restaurants with the highest and lowest number of votes.
#         Que 2] Analyze if there is a correlation between the number of votes and the rating of a restaurant.
#
#     Task 3 Price Range vs. Online Delivery and Table Booking
#
#         Que 1] Analyze if there is a relationship between the price range and the availability of online delivery and table booking.
#         Que 2] Determine if higher-priced restaurants are more likely to offer these services.

# %% [markdown]
#
#
#                                                                                           Perfrom By
#                                                                                           Satyavrat R. Bhisekar

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Data Set

# %%
Data = pd.read_csv("Dataset.csv")

# %% [markdown]
# # Perform EDA

# %%
# looking at first five records of the Dataset
Data.head()
# Out:
#    Restaurant ID                Restaurant Name  Country Code       City  \
# 0             53                          Amber             1  New Delhi
# 1             55                        Berco's             1  New Delhi
# 2             60               Colonel's Kababz             1  New Delhi
# 3             64  Diva - The Italian Restaurant             1  New Delhi
# 4             65                Drums of Heaven             1  New Delhi
#
#                                              Address                Locality  \
# 0                   N-19, Connaught Place, New Delhi         Connaught Place
# 1  G-2/43, Middle Circle, Connaught Place, New Delhi         Connaught Place
# 2  29, Defence Colony Market, Defence Colony, New...          Defence Colony
# 3  M-8A, M Block Market, Greater Kailash (GK) 2, ...  Greater Kailash (GK) 2
# 4  S-14, Green Park Extension, Green Park, New Delhi              Green Park
#
#                     Locality Verbose  Longitude   Latitude  \
# ...

# %%
# last five reecords
Data.tail()
# Out:
#       Restaurant ID        Restaurant Name  Country Code       City  \
# 9546       18499493                Zombiez             1  New Delhi
# 9547       18500618            Veg. Darbar             1  New Delhi
# 9548       18500628           Grill & Cafe             1    Gurgaon
# 9549       18500639  Chandni Chowk 2 China             1      Noida
# 9550       18500652        Mahek By Greenz             1    Gurgaon
#
#                                                 Address            Locality  \
# 9546  E 379, Khosla Complex, Samrat Apartment, Vasun...  Vasundhara Enclave
# 9547  Near Metro Pillar 682, Uttam Nagar West, Uttam...         Uttam Nagar
# 9548  48/5, Mahrauli Road, Near Government College, ...           Sector 14
# 9549                             H-38, Sector 51, Noida           Sector 51
# 9550      A 201, Belvedere Towers, DLF Phase 2, Gurgaon         DLF Phase 2
#
#                    Locality Verbose  Longitude   Latitude  \
# ...

# %%
# to know number of rows and columns
Data.shape
# Out:
# (9551, 21)

# %%
# to check data type of each column
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# to find null values in Dataset
Data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# Removing null values
Data.dropna()
# Out:
#       Restaurant ID                Restaurant Name  Country Code       City  \
# 0                53                          Amber             1  New Delhi
# 1                55                        Berco's             1  New Delhi
# 2                60               Colonel's Kababz             1  New Delhi
# 3                64  Diva - The Italian Restaurant             1  New Delhi
# 4                65                Drums of Heaven             1  New Delhi
# ...             ...                            ...           ...        ...
# 9546       18499493                        Zombiez             1  New Delhi
# 9547       18500618                    Veg. Darbar             1  New Delhi
# 9548       18500628                   Grill & Cafe             1    Gurgaon
# 9549       18500639          Chandni Chowk 2 China             1      Noida
# 9550       18500652                Mahek By Greenz             1    Gurgaon
#
# ...

# %%
# to know the columns names 
Data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# to check is there duplicate records.
Data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9546    False
# 9547    False
# 9548    False
# 9549    False
# 9550    False
# Length: 9551, dtype: bool

# %% [markdown]
# # Level - 1

# %% [markdown]
#   # Task  1  -- Top Cuisines

# %% [markdown]
# 1] Determine the top three most common cuisines in the dataset ?

# %%
Top_cuisine = Data["Cuisines"].value_counts()
Top_cuisine
# Out:
# Cuisines
# North Indian                                 936
# North Indian, Chinese                        511
# Chinese                                      354
# Fast Food                                    354
# North Indian, Mughlai                        334
#                                             ...
# Cafe, Chinese, Fast Food, Seafood              1
# Chinese, North Indian, Cafe                    1
# North Indian, Chinese, Mexican, Beverages      1
# Cafe, Italian, Mexican, Bakery                 1
# French, Mediterranean, European                1
# Name: count, Length: 1825, dtype: int64

# %% [markdown]
# Showing The Bargraph

# %%
x = list(Top_cuisine.keys()[0:6])
y = list(Top_cuisine[0:6])
plt.figure(figsize = (10,4))
plt.bar(x,y,width = 0.4)
plt.xlabel('Cuisines',fontsize = 11)
plt.ylabel('Count',fontsize = 11)
plt.title('Top Cuisine',fontsize = 13)
plt.show()

# %% [markdown]
# 2] Calculate the percentage of restaurants that serve each of the top cuisines ?

# %%
for i in Top_cuisine.keys():
    cui = Data[Data["Cuisines"] == i ]
    cui_count = cui['Cuisines'].count()
    if cui_count >= 354:
        Rest_val_count = cui['Restaurant Name'].value_counts()
        percent_cui = (Rest_val_count/cui_count)*100
        print('percent of rest that serve in ',i, '  is  ',percent_cui)
        
    #print(cui_count,"  and  ",Rest_val_count)
# Out:
# percent of rest that serve in  North Indian   is   Restaurant Name
# Wah Ji Wah                        0.961538
# Apni Rasoi                        0.747863
# Punjabi Tadka                     0.534188
# Aapki Rasoi                       0.427350
# Punjabi Chaap Corner              0.427350
#                                     ...
# Dharma Punjabi Dhaba              0.106838
# Khalsa Hindu Hotel                0.106838
# PM 2 AM Food Bank                 0.106838
# Prince Fried N Grilled Chicken    0.106838
# Mahek By Greenz                   0.106838
# Name: count, Length: 866, dtype: float64
# percent of rest that serve in  North Indian, Chinese   is   Restaurant Name
# Barbeque Nation            1.565558
# Wah Ji Wah                 1.565558
# SGF - Spice Grill Flame    0.978474
# Sandoz                     0.782779
# Apni Rasoi                 0.587084
#                              ...
# iGNiTE                     0.195695
# Flavours of Punjab         0.195695
# ...

# %%
North_indian = Data[Data["Cuisines"]=="North Indian"]
North_indian["Restaurant Name"].value_counts()
# Out:
# Restaurant Name
# Wah Ji Wah                        9
# Apni Rasoi                        7
# Punjabi Tadka                     5
# Aapki Rasoi                       4
# Punjabi Chaap Corner              4
#                                  ..
# Dharma Punjabi Dhaba              1
# Khalsa Hindu Hotel                1
# PM 2 AM Food Bank                 1
# Prince Fried N Grilled Chicken    1
# Mahek By Greenz                   1
# Name: count, Length: 866, dtype: int64

# %%
North_Indian_Chinese = Data[Data["Cuisines"]== "North Indian, Chinese"]
North_Indian_Chinese["Restaurant Name"].value_counts()
# Out:
# Restaurant Name
# Barbeque Nation            8
# Wah Ji Wah                 8
# SGF - Spice Grill Flame    5
# Sandoz                     4
# Apni Rasoi                 3
#                           ..
# iGNiTE                     1
# Flavours of Punjab         1
# Chilli Pepper              1
# City Hut                   1
# Chandni Chowk 2 China      1
# Name: count, Length: 465, dtype: int64

# %%
Chinese = Data[Data['Cuisines']=="Chinese"]
Chinese['Restaurant Name'].value_counts()
# Out:
# Restaurant Name
# Yo! China             9
# Mainland China        6
# China Town            5
# Flirty Momo's         5
# Chinese Hut           4
#                      ..
# Namaste Restaurant    1
# Arora Snacks          1
# The Chinese Hut       1
# Chin Pokli            1
# Chinese Corner        1
# Name: count, Length: 310, dtype: int64

# %% [markdown]
# # Task 2 -- city analysis

# %% [markdown]
# 1] Identify the city with the highest number of restaurants in the dataset ?

# %%
City = Data['City'].value_counts()
City
# Out:
# City
# New Delhi        5473
# Gurgaon          1118
# Noida            1080
# Faridabad         251
# Ghaziabad          25
#                  ...
# Randburg            1
# Princeton           1
# Quezon City         1
# Tagaytay City       1
# Flaxton             1
# Name: count, Length: 141, dtype: int64

# %% [markdown]
# 2] Calculate the average rating for restaurants in each city ?

# %%
Average_rating = Data[Data['City']=='New Delhi']
Average_rating['Aggregate rating']
np.average(Average_rating['Aggregate rating']).round(2)
# Out:
# 2.44

# %%
for i in City.keys():
    Average_rating = Data[Data['City'] == i]
    print(i,"  --->  ",np.average(Average_rating['Aggregate rating']).round(2))
# Out:
# New Delhi   --->   2.44
# Gurgaon   --->   2.65
# Noida   --->   2.04
# Faridabad   --->   1.87
# Ghaziabad   --->   2.85
# Amritsar   --->   3.69
# Lucknow   --->   4.2
# Ahmedabad   --->   4.16
# Bhubaneshwar   --->   3.98
# Guwahati   --->   4.19
# S��o Paulo   --->   3.53
# Manchester   --->   4.04
# Bras�_lia   --->   3.49
# Auckland   --->   4.28
# Wellington City   --->   4.25
# Cape Town   --->   4.11
# Doha   --->   4.06
# London   --->   4.54
# Edinburgh   --->   4.09
# Orlando   --->   4.47
# Tampa Bay   --->   4.41
# Ankara   --->   4.31
# Rest of Hawaii   --->   4.41
# Des Moines   --->   4.24
# Birmingham   --->   3.68
# Athens   --->   4.2
# Albany   --->   3.56
# Abu Dhabi   --->   4.3
# Waterloo   --->   3.65
# Valdosta   --->   3.72
# Sioux City   --->   3.77
# Savannah   --->   4.16
# Pocatello   --->   3.49
# Pensacola   --->   4.2
# Macon   --->   4.12
# Gainesville   --->   4.03
# Dubuque   --->   3.54
# Davenport   --->   3.72
# Dalton   --->   4.11
# ...

# %%
city_ = list()
Avg_ = list()
for i in City.keys():
    Average_rating = Data[Data['City']== i]
    city_.append(i)
    Avg_.append(np.average(Average_rating['Aggregate rating']).round(2))
    #print(i,"  --->  ",np.average(Average_rating['Aggregate rating']).round(2))
    #Avg[i] = np.average(Average_rating['Aggregate rating']).round(2)
    #print(i,"  --->  ",np.average(Average_rating['Aggregate rating']).round(2))
Avg = pd.DataFrame(list(zip(city_,Avg_)),columns = ["City","Average rating"])
Avg
# Out:
#               City  Average rating
# 0        New Delhi            2.44
# 1          Gurgaon            2.65
# 2            Noida            2.04
# 3        Faridabad            1.87
# 4        Ghaziabad            2.85
# ..             ...             ...
# 136       Randburg            4.30
# 137      Princeton            4.00
# 138    Quezon City            4.80
# 139  Tagaytay City            4.50
# 140        Flaxton            3.50
#
# [141 rows x 2 columns]

# %% [markdown]
# 3] Determine the city with the highest average rating ?

# %%
city_ = list()
Avg_ = list()
for i in City.keys():
    Average_rating = Data[Data['City']== i]
    city_.append(i)
    Avg_.append(np.average(Average_rating['Aggregate rating']).round(2))
Avg = pd.DataFrame(list(zip(city_,Avg_)),columns = ["City","Average rating"])
Avg.sort_values("Average rating",ascending = False)
# Out:
#                  City  Average rating
# 88         Inner City            4.90
# 138       Quezon City            4.80
# 93        Makati City            4.65
# 86         Pasig City            4.63
# 84   Mandaluyong City            4.62
# ..                ...             ...
# 0           New Delhi            2.44
# 98          Mc Millan            2.40
# 129         Montville            2.40
# 2               Noida            2.04
# 3           Faridabad            1.87
#
# [141 rows x 2 columns]

# %% [markdown]
# # Task 3 --  Price Range Distribution

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 1] Create a histogram or bar chart to visualize the distribution of price ranges among the restaurants ?

# %%
Restaurants = Data['Restaurant Name'].value_counts()
Restaurants
# Out:
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Moets Curry Leaf Express     1
# Chicken Bytes                1
# Rao's Meeting Point          1
# Dilli 6 Express              1
# Mahek By Greenz              1
# Name: count, Length: 7446, dtype: int64

# %% [markdown]
# Showing The Bar-Graph

# %%
Price_range = list()
for i in Restaurants.keys():
    Res = Data[Data['Restaurant Name'] == i]
    Price = Res['Price range'].max()
    Price_range.append(Price)

# %%
x = list(Restaurants.keys()[0:10])
y = Price_range[0:10]
plt.figure(figsize = (10,4))
plt.bar(x,y,width = 0.4 )
plt.xlabel('Restaurants')
plt.ylabel('Reice range')
plt.xticks(rotation=30)
plt.title("Restaurants by Price range",fontsize=13)
plt.show()

# %% [markdown]
# 2] Calculate the percentage of restaurants in each price range category ?

# %%
Rest = Data["Restaurant Name"].count()
price_range = Data["Price range"].value_counts()
per_restaurants = (price_range/Rest)*100
per_restaurants
# Out:
# Price range
# 1    46.529159
# 2    32.593446
# 3    14.741912
# 4     6.135483
# Name: count, dtype: float64

# %% [markdown]
# Showing The Pie-Chart

# %%
plt.pie(price_range,labels = price_range.keys(),autopct='%1.2f%%')
plt.show()

# %% [markdown]
# # Task 4 -- Online Delivery

# %% [markdown]
# 1] Determine the percentage of restaurants that offer online delivery ?

# %%
Rest = Data["Restaurant Name"].count()
online_delivery = Data['Has Online delivery'].value_counts()
online_del_percent = (online_delivery/Rest)*100
online_del_percent
# Out:
# Has Online delivery
# No     74.337766
# Yes    25.662234
# Name: count, dtype: float64

# %% [markdown]
# Showing the Pie-Chart

# %%
plt.pie(online_delivery,labels = online_delivery.keys(),autopct='%1.2f%%')
plt.show()

# %% [markdown]
# 2] Compare the average ratings of restaurants with and without online delivery ?

# %%
Comp_avg = Data[['Restaurant Name','Aggregate rating','Has Table booking','Has Online delivery']]
Comp_avg.sort_values('Aggregate rating',ascending = False)
# Out:
#                     Restaurant Name  Aggregate rating Has Table booking  \
# 4817               Silantro Fil-Mex               4.9                No
# 6237            Carnival By Tresind               4.9               Yes
# 1939                Barbeque Nation               4.9                No
# 4994             Braseiro da G��vea               4.9                No
# 5389  McGuire's Irish Pub & Brewery               4.9                No
# ...                             ...               ...               ...
# 3787          Sanjha Chulah Babe Da               0.0                No
# 3782                   Chocofairies               0.0                No
# 3780                  Singh Chicken               0.0                No
# 3777             Lasha Chinese Food               0.0                No
# 9550                Mahek By Greenz               0.0                No
#
#      Has Online delivery
# 4817                  No
# 6237                  No
# ...

# %% [markdown]
# # Level 2

# %% [markdown]
# # Task 1 -- Restaurant Ratings

# %% [markdown]
# 1] Analyze the distribution of aggregate ratings and determine the most common rating range ?

# %%
Agg_rating = Data['Aggregate rating'].unique()
Agg_rating
# Out:
# array([2.6, 3.9, 3.2, 3.8, 3.5, 4. , 3.3, 4.2, 2.7, 3.6, 3.7, 2.5, 1.9,
#        3.1, 3.4, 2.8, 2.3, 2.4, 3. , 2. , 2.9, 2.2, 2.1, 4.4, 4.1, 0. ,
#        4.3, 4.5, 1.8, 4.9, 4.6, 4.8, 4.7])

# %%
Agg_rating = Data['Aggregate rating'].value_counts()
pd.DataFrame(Agg_rating)
# Out:
#                   count
# Aggregate rating
# 0.0                2148
# 3.2                 522
# 3.1                 519
# 3.4                 498
# 3.3                 483
# 3.5                 480
# 3.0                 468
# 3.6                 458
# 3.7                 427
# 3.8                 400
# 2.9                 381
# 3.9                 335
# 2.8                 315
# 4.1                 274
# 4.0                 266
# 2.7                 250
# 4.2                 221
# 2.6                 191
# 4.3                 174
# 4.4                 144
# 2.5                 110
# 4.5                  95
# 2.4                  87
# 4.6                  78
# 4.9                  61
# 2.3                  47
# 4.7                  42
# 2.2                  27
# 4.8                  25
# 2.1                  15
# 2.0                   7
# 1.9                   2
# 1.8                   1

# %% [markdown]
# 2] Calculate the average number of votes received by restaurants ?

# %%
Restaurants = Data['Restaurant Name'].value_counts()
rest = list()
num_v = list()
for i in Restaurants.keys():
    Rest = Data[Data['Restaurant Name']== i]
    Num_votes = np.average(Rest["Votes"]).round(2)
    rest.append(i)
    num_v.append(Num_votes)
    #print(i,'---> average votes :- ',Num_votes)
votses_by_rest = pd.DataFrame(list(zip(rest,num_v)),columns = ["Restaurants","Votes"])
votses_by_rest.sort_values('Votes',ascending = False)
# Out:
#            Restaurants    Votes
# 4086              Toit  10934.0
# 6620  Hauz Khas Social   7931.0
# 4095         Peter Cat   7574.0
# 4029       Big Brewsky   5705.0
# 4085   The Black Pearl   5385.0
# ...                ...      ...
# 3104     Spices Affair      0.0
# 3103     Welcome Rasoi      0.0
# 3102  The Pizza Family      0.0
# 3101     Bala Ji Rasoi      0.0
# 7445   Mahek By Greenz      0.0
#
# [7446 rows x 2 columns]

# %% [markdown]
# # Task 2 -- Cuisine Combination

# %% [markdown]
# 1] Identify the most common combinations of cuisines in the dataset ?

# %%
Most_cuisines = Data['Cuisines'].value_counts()
Most_cuisines
# Out:
# Cuisines
# North Indian                                 936
# North Indian, Chinese                        511
# Chinese                                      354
# Fast Food                                    354
# North Indian, Mughlai                        334
#                                             ...
# Cafe, Chinese, Fast Food, Seafood              1
# Chinese, North Indian, Cafe                    1
# North Indian, Chinese, Mexican, Beverages      1
# Cafe, Italian, Mexican, Bakery                 1
# French, Mediterranean, European                1
# Name: count, Length: 1825, dtype: int64

# %% [markdown]
# 2] Determine if certain cuisine combinations tend to have higher ratings ?

# %%
Cuisines = Data['Cuisines'].value_counts()
Cus = list()
High_rate = list()
for i in Cuisines.keys():
    Cuisi_n = Data[Data['Cuisines'] == i]
    H_rate = np.max(Cuisi_n['Aggregate rating'])
    Cus.append(i)
    High_rate.append(H_rate)
cuisines_High_rating = pd.DataFrame(list(zip(Cus,High_rate)),columns = ['Cuisines','High_Rates'])
cuisines_High_rating.sort_values("High_Rates",ascending = False)
# Out:
#                                       Cuisines  High_Rates
# 0                                 North Indian         4.9
# 272                          Sunda, Indonesian         4.9
# 127                                      Steak         4.9
# 1553                   European, Asian, Indian         4.9
# 500                            Sushi, Japanese         4.9
# ...                                        ...         ...
# 1420                             Bakery, Pizza         0.0
# 886   American, Italian, North Indian, Chinese         0.0
# 885             North Indian, Mughlai, Mughlai         0.0
# 363                            Chinese, Mithai         0.0
# 912             Italian, Continental, American         0.0
#
# [1825 rows x 2 columns]

# %% [markdown]
# # Task 3 -- Geographic Analysis

# %% [markdown]
# 1] Plot the locations of restaurants on a map using longitude and latitude coordinates.

# %% [markdown]
# # Level 3

# %% [markdown]
# # Task 1 -- Restaurant Reviews

# %% [markdown]
# 1] Analyze the text reviews to identify the most common positive and negative keywords ?

# %%
Text = Data['Rating text'].value_counts()
Text
# Out:
# Rating text
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: count, dtype: int64

# %% [markdown]
# 2] Calculate the average length of reviews and explore if there is a relationship between review length and rating ?

# %%
Text_ct = Data['Rating text'].count()
Text = Data['Rating text'].value_counts()
Text_percent = ((Text/Text_ct)*100)
Text_percent
# Out:
# Rating text
# Average      39.126793
# Not rated    22.489792
# Good         21.987226
# Very Good    11.297246
# Excellent     3.151502
# Poor          1.947440
# Name: count, dtype: float64

# %% [markdown]
# Showing the Pie-Chart

# %%
plt.pie(Text,labels = Text.keys(),autopct='%1.2f%%')
plt.show()

# %%
Rating_text = list()
Agg_max_rate = list()
Agg_min_rate = list()
for i in Text.keys():
    Rate_text = Data[Data["Rating text"] == i]
    Agg_max_rating = np.max(Rate_text["Aggregate rating"])
    Agg_min_rating = np.min(Rate_text["Aggregate rating"])
    Rating_text.append(i)
    Agg_max_rate.append(Agg_max_rating)
    Agg_min_rate.append(Agg_min_rating)
review_len_rating = pd.DataFrame(list(zip(Rating_text,Agg_max_rate,Agg_min_rate)),columns = ["Rating text","Max rating","Min rating"])
review_len_rating
# Out:
#   Rating text  Max rating  Min rating
# 0     Average         3.4         2.5
# 1   Not rated         0.0         0.0
# 2        Good         3.9         3.5
# 3   Very Good         4.4         4.0
# 4   Excellent         4.9         4.5
# 5        Poor         2.4         1.8

# %% [markdown]
# # Task 2 --  Votes Analysis

# %% [markdown]
# 1] Identify the restaurants with the highest and lowest number of votes.

# %%
Restaurant = Data[["Restaurant Name","Votes"]]
Restaurant.sort_values('Votes',ascending= False)
# Out:
#                 Restaurant Name  Votes
# 1954                       Toit  10934
# 1953                   Truffles   9667
# 3283           Hauz Khas Social   7931
# 1937                  Peter Cat   7574
# 1957  AB's - Absolute Barbecues   6907
# ...                         ...    ...
# 7066         Nehra's Food Point      0
# 7068          Chinese Fast Food      0
# 7069                Foodieholic      0
# 8516                Malt n Brew      0
# 9550            Mahek By Greenz      0
#
# [9551 rows x 2 columns]

# %%
#Restaurant = Data["Restaurant Name"].value_counts()
#Votes = list()
#for i in Restaurant.keys():
#    Res_t = Data[Data["Restaurant Name"] == i]
#    vot_es = np.sum(Res_t['Votes'])
#    Votes.append(vot_es)
#High_low_votes = pd.DataFrame(list(zip(rest,Votes)),columns = ["Restaurants","Votes"])
#High_low_votes.sort_values('Votes',ascending= False)

# %% [markdown]
# 2] Analyze if there is a correlation between the number of votes and the rating of a restaurant ?

# %%
Votes_rating = Data[["Restaurant Name","Aggregate rating","Votes"]]
Votes_rating.sort_values('Votes',ascending = False)
# Out:
#                 Restaurant Name  Aggregate rating  Votes
# 1954                       Toit               4.8  10934
# 1953                   Truffles               4.7   9667
# 3283           Hauz Khas Social               4.3   7931
# 1937                  Peter Cat               4.3   7574
# 1957  AB's - Absolute Barbecues               4.6   6907
# ...                         ...               ...    ...
# 7066         Nehra's Food Point               0.0      0
# 7068          Chinese Fast Food               0.0      0
# 7069                Foodieholic               0.0      0
# 8516                Malt n Brew               0.0      0
# 9550            Mahek By Greenz               0.0      0
#
# [9551 rows x 3 columns]

# %%
Restaurant = Data['Restaurant Name'].value_counts()
Votes = list()
Agg_rate = list()
for i in Restaurant.keys():
    Res_t = Data[Data['Restaurant Name'] == i]
    vot_es = np.sum(Res_t['Votes'])
    Agg_rating = np.max(Res_t['Aggregate rating'])
    Agg_rate.append(Agg_rating)
    Votes.append(vot_es)
Restaurant_Votes_rating = pd.DataFrame(list(zip(rest,Agg_rate,Votes)),columns = ['Restaurants','Agg_rate','Votes'])
Restaurant_Votes_rating.sort_values('Votes',ascending = False)
# Out:
#                     Restaurants  Agg_rate  Votes
# 9               Barbeque Nation       4.9  28142
# 124   AB's - Absolute Barbecues       4.9  13400
# 4086                       Toit       4.8  10934
# 138                   Big Chill       4.6  10853
# 66                   Farzi Cafe       4.5  10098
# ...                         ...       ...    ...
# 3104              Spices Affair       0.0      0
# 3103              Welcome Rasoi       0.0      0
# 3102           The Pizza Family       0.0      0
# 3101              Bala Ji Rasoi       0.0      0
# 7445            Mahek By Greenz       0.0      0
#
# [7446 rows x 3 columns]

# %% [markdown]
# # Task 3 -- Price Range vs. Online Delivery and Table Booking

# %% [markdown]
# 1] Analyze if there is a relationship between the price range and the availability of online delivery and table booking ?

# %%
Analyse = Data[['Restaurant Name','Price range','Has Online delivery','Has Table booking']]
Analyse
# Out:
#                     Restaurant Name  Price range Has Online delivery  \
# 0                             Amber            3                 Yes
# 1                           Berco's            3                 Yes
# 2                  Colonel's Kababz            2                  No
# 3     Diva - The Italian Restaurant            4                 Yes
# 4                   Drums of Heaven            3                 Yes
# ...                             ...          ...                 ...
# 9546                        Zombiez            2                  No
# 9547                    Veg. Darbar            1                  No
# 9548                   Grill & Cafe            2                  No
# 9549          Chandni Chowk 2 China            1                  No
# 9550                Mahek By Greenz            1                  No
#
#      Has Table booking
# 0                  Yes
# 1                  Yes
# 2                  Yes
# 3                  Yes
# ...

# %% [markdown]
# 2] Determine if higher-priced restaurants are more likely to offer these services ?

# %%
Analyse.sort_values("Price range",ascending = False)
# Out:
#                                   Restaurant Name  Price range  \
# 4893                          Skye - Hotel Unique            4
# 5123                            Mama's Fish House            4
# 5116                               Duke's Waikiki            4
# 5114                       Edison: Food+Drink Lab            4
# 683   Atrium Bar  & Lounge - The Suryaa New Delhi            4
# ...                                           ...          ...
# 3060                          Shudh Vaishno Hotel            1
# 6224                              Grills N Chills            1
# 6223                           Nirula's Ice Cream            1
# 3061                          Republic of Chicken            1
# 9550                              Mahek By Greenz            1
#
#      Has Online delivery Has Table booking
# 4893                  No                No
# 5123                  No                No
# 5116                  No                No
# ...

# %%
offer_both = Analyse.groupby(['Has Online delivery','Has Table booking'])
off_ = offer_both.get_group(('Yes','Yes'))
Offer_both = pd.DataFrame(off_)
Offer_both.sort_values('Price range',ascending = False)
# Out:
#               Restaurant Name  Price range Has Online delivery  \
# 910   The Great Kabab Factory            4                 Yes
# 313              TGI Friday's            4                 Yes
# 5852   TFK - The Flaming Kick            4                 Yes
# 925             21 Gun Salute            4                 Yes
# 953         Spaghetti Kitchen            4                 Yes
# ...                       ...          ...                 ...
# 3927          Fork with Stick            2                 Yes
# 3973               New Kadimi            2                 Yes
# 813                  Kamboj's            2                 Yes
# 4205      Nizam's Kathi Kabab            2                 Yes
# 6888               Wah Ji Wah            1                 Yes
#
#      Has Table booking
# 910                Yes
# 313                Yes
# 5852               Yes
# 925                Yes
# 953                Yes
# ...                ...
# 3927               Yes
# ...

# %% [markdown]
#     --> Python programming and Pandas library is data manipulation will help us extract valuable insights from large datasets and drive informed decision-making.
#     --> Whether it's cleaning and preprocessing data, performing statistical analysis, or creating data visualizations.
#     play's a crucial role in delivering meaningful results.
